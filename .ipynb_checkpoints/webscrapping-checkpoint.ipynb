# %%
from bs4 import BeautifulSoup

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service

# %%
import time

# %%
#You need to have driver corresponding to your Google Chrome browser or update browser
from selenium.webdriver.common.by import By

# %%
#CS  - CS 
#EC  - ECE
#CI  - AI
#CSE - CS+AI
RESULT_FOR="EC"
YEAR="21"

# %%
usns=[]
# Change Range According to Number of students
if(RESULT_FOR!="CSE"):
    #Students USN 
    for i in range(1,366):
        usn='01FE'+YEAR+'B'+RESULT_FOR+((3-len(str(i)))*'0')+str(i)
        usns.append(usn)
    
else:
    #CS + AI USNS
    for i in range(2,367):
        usn='01FE'+YEAR+'BCS'+((3-len(str(i)))*'0')+str(i)
        usns.append(usn)
    for i in range(1,63):
        usn='01FE'+YEAR+'BCI'+((3-len(str(i)))*'0')+str(i)
        usns.append(usn)

# %% [markdown]
# ### Run the cell below and wait until Google Chrome opens

# %%
url="https://eresults.kletech.ac.in/kletecheven/index.php"

#This is the path name of chrome driver on my PC
service = Service()
options = webdriver.ChromeOptions()
driver = webdriver.Chrome(service=service, options=options)

driver.get(url)
driver.maximize_window()

# %% [markdown]
# ### When website Opens then change the captcha below and run the cell
#
# ### My college website has a glitch that its captcha doesn't change if we navigate back on the website

# %%
#put the captcha as shown in website and run this cell
captcha="DBWG1" #this was the current captcha when I was using

# %%
#For each USN I am scrapping the details
result={}
result['NAME']=[None]*len(usns)
result['USN']=['None']*len(usns)
result['SGPA']=[None]*len(usns)
result['CGPA']=[None]*len(usns)

for number in range(len(usns)):
    username=usns[number]
    driver.find_element(by=By.NAME,value="usn").send_keys(username)
    driver.find_element(by=By.NAME,value="osolCatchaTxt").send_keys(captcha)

    # driver.find_element_by_formaction("index.php?option=com_examresult&task=getResult").click()
    driver.find_element(By.XPATH, '//button[text()="Result"]').click()
        
    try:
        name=driver.find_element(By.XPATH,'//div[contains(@class,"uk-card uk-card-body stu-data stu-data1")]')
        table=driver.find_element(By.XPATH,'//table[contains(@class,"uk-table uk-table-striped res-table")]/tbody')
        sgpa=driver.find_element(By.XPATH,'//div[contains(@class,"uk-card uk-card-default uk-card-body credits-sec3")]')
        cgpa=driver.find_element(By.XPATH,'//div[contains(@class,"uk-card uk-card-default uk-card-body credits-sec4")]')
        sub=table.text.split('\n')
        grades=""
        print()
        print('=======================')
        print('Name:',name.text)
        print('USN:',username)
        print('=======SUBJECTS========')
        for i in range(len(sub)):
            t=sub[i].split(" ")
            title=" ".join(t[1:-3])
            grades=t[-1]
            print(title,':',grades)
            if(result.get(title)==None):
                result[title]=[None]*len(usns)
            result[title][number]=grades

        #print(grades)
        print('=======SUBJECTS========')
        print('SGPA:',sgpa.text[5:])
        print('CGPA',cgpa.text[5:])
        print('=======================')    
        print()
        result['NAME'][number]=name.text
        result['USN'][number]=username
        result['SGPA'][number]=sgpa.text[5:]
        result['CGPA'][number]=cgpa.text[5:]
        #file.write('\n'+(username)+','+(name.text)+','+(sgpa.text[5:])+','+(cgpa.text[5:])+','+grades)
    except:
        print("Error in fetching values for USN",username)
        
    driver.back() #navigating back by clicking back button

    driver.find_element(by=By.NAME,value="usn").clear() #clearing the already filled detail
    driver.find_element(by=By.NAME,value="osolCatchaTxt").clear() #Clearing the CAPTCHA field as it will be Entered again

print('==========')
print("Completed")
print('==========')
#print(result)
# Out:
# Error in fetching values for USN 01FE21BEC001
# Error in fetching values for USN 01FE21BEC002
# Error in fetching values for USN 01FE21BEC003
# Error in fetching values for USN 01FE21BEC004
# Error in fetching values for USN 01FE21BEC005
# Error in fetching values for USN 01FE21BEC006
# Error in fetching values for USN 01FE21BEC007
# Error in fetching values for USN 01FE21BEC008
# Error in fetching values for USN 01FE21BEC009
# Error in fetching values for USN 01FE21BEC010
# Error in fetching values for USN 01FE21BEC011
# Error in fetching values for USN 01FE21BEC012
# Error in fetching values for USN 01FE21BEC013
# Error in fetching values for USN 01FE21BEC014
# Error in fetching values for USN 01FE21BEC015
# Error in fetching values for USN 01FE21BEC016
# Error in fetching values for USN 01FE21BEC017
# Error in fetching values for USN 01FE21BEC018
# Error in fetching values for USN 01FE21BEC019
# Error in fetching values for USN 01FE21BEC020
# Error in fetching values for USN 01FE21BEC021
# Error in fetching values for USN 01FE21BEC022
# Error in fetching values for USN 01FE21BEC023
# Error in fetching values for USN 01FE21BEC024
# Error in fetching values for USN 01FE21BEC025
# Error in fetching values for USN 01FE21BEC026
# Error in fetching values for USN 01FE21BEC027
# Error in fetching values for USN 01FE21BEC028
# Error in fetching values for USN 01FE21BEC029
# Error in fetching values for USN 01FE21BEC030
# Error in fetching values for USN 01FE21BEC031
# Error in fetching values for USN 01FE21BEC032
# Error in fetching values for USN 01FE21BEC033
# Error in fetching values for USN 01FE21BEC034
# Error in fetching values for USN 01FE21BEC035
# Error in fetching values for USN 01FE21BEC036
# Error in fetching values for USN 01FE21BEC037
# Error in fetching values for USN 01FE21BEC038
# Error in fetching values for USN 01FE21BEC039
# Error in fetching values for USN 01FE21BEC040
# Error in fetching values for USN 01FE21BEC041
# Error in fetching values for USN 01FE21BEC042
# Error in fetching values for USN 01FE21BEC043
# Error in fetching values for USN 01FE21BEC044
# Error in fetching values for USN 01FE21BEC045
# Error in fetching values for USN 01FE21BEC046
# Error in fetching values for USN 01FE21BEC047
# Error in fetching values for USN 01FE21BEC048
# Error in fetching values for USN 01FE21BEC049
# Error in fetching values for USN 01FE21BEC050
# Error in fetching values for USN 01FE21BEC051
# Error in fetching values for USN 01FE21BEC052
# Error in fetching values for USN 01FE21BEC053
# Error in fetching values for USN 01FE21BEC054
# Error in fetching values for USN 01FE21BEC055
# Error in fetching values for USN 01FE21BEC056
# Error in fetching values for USN 01FE21BEC057
# Error in fetching values for USN 01FE21BEC058
# Error in fetching values for USN 01FE21BEC059
# Error in fetching values for USN 01FE21BEC060
# Error in fetching values for USN 01FE21BEC061
# Error in fetching values for USN 01FE21BEC062
# Error in fetching values for USN 01FE21BEC063
# Error in fetching values for USN 01FE21BEC064
# Error in fetching values for USN 01FE21BEC065
# Error in fetching values for USN 01FE21BEC066
# Error in fetching values for USN 01FE21BEC067
# Error in fetching values for USN 01FE21BEC068
# Error in fetching values for USN 01FE21BEC069
# Error in fetching values for USN 01FE21BEC070
# Error in fetching values for USN 01FE21BEC071
# Error in fetching values for USN 01FE21BEC072
# Error in fetching values for USN 01FE21BEC073
# Error in fetching values for USN 01FE21BEC074
# Error in fetching values for USN 01FE21BEC075
# Error in fetching values for USN 01FE21BEC076
# Error in fetching values for USN 01FE21BEC077
# Error in fetching values for USN 01FE21BEC078
# Error in fetching values for USN 01FE21BEC079
# Error in fetching values for USN 01FE21BEC080
# Error in fetching values for USN 01FE21BEC081
# Error in fetching values for USN 01FE21BEC082
# Error in fetching values for USN 01FE21BEC083
# Error in fetching values for USN 01FE21BEC084
# Error in fetching values for USN 01FE21BEC085
# Error in fetching values for USN 01FE21BEC086
# Error in fetching values for USN 01FE21BEC087
# Error in fetching values for USN 01FE21BEC088
# Error in fetching values for USN 01FE21BEC089
# Error in fetching values for USN 01FE21BEC090
# Error in fetching values for USN 01FE21BEC091
# Error in fetching values for USN 01FE21BEC092
# Error in fetching values for USN 01FE21BEC093
# Error in fetching values for USN 01FE21BEC094
# Error in fetching values for USN 01FE21BEC095
# Error in fetching values for USN 01FE21BEC096
# Error in fetching values for USN 01FE21BEC097
# Error in fetching values for USN 01FE21BEC098
# Error in fetching values for USN 01FE21BEC099
# Error in fetching values for USN 01FE21BEC100
# Error in fetching values for USN 01FE21BEC101
# Error in fetching values for USN 01FE21BEC102
# Error in fetching values for USN 01FE21BEC103
# Error in fetching values for USN 01FE21BEC104
# Error in fetching values for USN 01FE21BEC105
# Error in fetching values for USN 01FE21BEC106
# Error in fetching values for USN 01FE21BEC107
# Error in fetching values for USN 01FE21BEC108
# Error in fetching values for USN 01FE21BEC109
# Error in fetching values for USN 01FE21BEC110
# Error in fetching values for USN 01FE21BEC111
# Error in fetching values for USN 01FE21BEC112
# Error in fetching values for USN 01FE21BEC113
# Error in fetching values for USN 01FE21BEC114
# Error in fetching values for USN 01FE21BEC115
# Error in fetching values for USN 01FE21BEC116
# Error in fetching values for USN 01FE21BEC117
# Error in fetching values for USN 01FE21BEC118
# Error in fetching values for USN 01FE21BEC119
# Error in fetching values for USN 01FE21BEC120
# Error in fetching values for USN 01FE21BEC121
# Error in fetching values for USN 01FE21BEC122
# Error in fetching values for USN 01FE21BEC123
# Error in fetching values for USN 01FE21BEC124
# Error in fetching values for USN 01FE21BEC125
# Error in fetching values for USN 01FE21BEC126
# Error in fetching values for USN 01FE21BEC127
# Error in fetching values for USN 01FE21BEC128
# Error in fetching values for USN 01FE21BEC129
# Error in fetching values for USN 01FE21BEC130
# Error in fetching values for USN 01FE21BEC131
# Error in fetching values for USN 01FE21BEC132
# Error in fetching values for USN 01FE21BEC133
# Error in fetching values for USN 01FE21BEC134
# Error in fetching values for USN 01FE21BEC135
# Error in fetching values for USN 01FE21BEC136
# Error in fetching values for USN 01FE21BEC137

# %%
import pandas as pd
df=pd.DataFrame.from_dict(result)
df = df[df['USN'].str.contains('None') == False]
df.to_csv('result_B'+RESULT_FOR+'_'+YEAR+'.csv',index=False)
